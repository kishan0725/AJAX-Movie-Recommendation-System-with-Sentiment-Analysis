# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 262  DECEMBER         25             Holmes & Watson
# 263  DECEMBER         25                        Vice
# 264  DECEMBER         25         On the Basis of Sex
# 265  DECEMBER         25                   Destroyer
# 266  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                 Production company  \
# 0       Universal Pictures / Blumhouse Productions
# 1                           Vertical Entertainment
# 2                                Momentum Pictures
# 3                             Samuel Goldwyn Films
# 4    Lionsgate / StudioCanal / The Picture Company
# ..                                             ...
# 262   Columbia Pictures / Gary Sanchez Productions
# 263      Annapurna Pictures / Plan B Entertainment
# 264                                 Focus Features
# 265                             Annapurna Pictures
# 266                                        Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 266  David Slade (director); Charlie Brooker (scree...
#
#                                        Genre   Ref.
# 0                           Horror, Thriller    [2]
# 1                                      Drama    [3]
# 2                           Action, Thriller    [4]
# 3                                      Drama    [5]
# 4    Action, Crime, Drama, Mystery, Thriller    [6]
# ..                                       ...    ...
# 262                          Mystery, Comedy  [162]
# 263                         Biography, Drama  [136]
# 264                         Biography, Drama  [223]
# 265                          Crime, Thriller  [256]
# 266                         Sci-Fi, Thriller  [257]
#
# [267 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','Genre']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 266  David Slade (director); Charlie Brooker (scree...
#
#                                        Genre
# 0                           Horror, Thriller
# 1                                      Drama
# 2                           Action, Thriller
# 3                                      Drama
# 4    Action, Crime, Drama, Mystery, Thriller
# ..                                       ...
# 262                          Mystery, Comedy
# 263                         Biography, Drama
# 264                         Biography, Drama
# 265                          Crime, Thriller
# 266                         Sci-Fi, Thriller
#
# [267 rows x 3 columns]

# %%
df_2018['genres'] = df_2018['Genre'].str.replace(',', '')
# Out:
# /home/kishan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /home/kishan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /home/kishan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 266  David Slade (director); Charlie Brooker (scree...
#
#                                        Genre  \
# 0                           Horror, Thriller
# 1                                      Drama
# 2                           Action, Thriller
# 3                                      Drama
# 4    Action, Crime, Drama, Mystery, Thriller
# ..                                       ...
# 262                          Mystery, Comedy
# 263                         Biography, Drama
# 264                         Biography, Drama
# 265                          Crime, Thriller
# 266                         Sci-Fi, Thriller
#
#                                   genres       director_name     actor_1_name  \
# 0                        Horror Thriller        Adam Robitel        Lin Shaye
# 1                                  Drama    Lauren Wolkstein    Alex Pettyfer
# 2                        Action Thriller          Simon West   Dominic Cooper
# 3                                  Drama    Warwick Thornton      Bryan Brown
# 4    Action Crime Drama Mystery Thriller  Jaume Collet-Serra      Liam Neeson
# ..                                   ...                 ...              ...
# 262                       Mystery Comedy          Etan Cohen     Will Ferrell
# 263                      Biography Drama          Adam McKay   Christian Bale
# 264                      Biography Drama          Mimi Leder   Felicity Jones
# 265                       Crime Thriller        Karyn Kusama    Nicole Kidman
# 266                      Sci-Fi Thriller         David Slade  Fionn Whitehead
#
#                actor_2_name    actor_3_name
# 0             Angus Sampson  Leigh Whannell
# 1    James Freedson-Jackson   Emily Althaus
# 2            Austin Stowell      Gemma Chan
# 3                 Sam Neill             NaN
# 4              Vera Farmiga  Patrick Wilson
# ..                      ...             ...
# 262          John C. Reilly    Rebecca Hall
# 263               Amy Adams    Steve Carell
# 264            Armie Hammer  Justin Theroux
# 265          Sebastian Stan    Toby Kebbell
# 266            Will Poulter   Asim Chaudhry
#
# [267 rows x 8 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 262          Etan Cohen     Will Ferrell          John C. Reilly
# 263          Adam McKay   Christian Bale               Amy Adams
# 264          Mimi Leder   Felicity Jones            Armie Hammer
# 265        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 266         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                               genres  \
# 0    Leigh Whannell                      Horror Thriller
# 1     Emily Althaus                                Drama
# 2        Gemma Chan                      Action Thriller
# 3               NaN                                Drama
# 4    Patrick Wilson  Action Crime Drama Mystery Thriller
# ..              ...                                  ...
# 262    Rebecca Hall                       Mystery Comedy
# 263    Steve Carell                      Biography Drama
# 264  Justin Theroux                      Biography Drama
# 265    Toby Kebbell                       Crime Thriller
# 266   Asim Chaudhry                      Sci-Fi Thriller
#
#                     movie_title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
# [267 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 262          Etan Cohen     Will Ferrell          John C. Reilly
# 263          Adam McKay   Christian Bale               Amy Adams
# 264          Mimi Leder   Felicity Jones            Armie Hammer
# 265        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 266         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                               genres  \
# 0    Leigh Whannell                      Horror Thriller
# 1     Emily Althaus                                Drama
# 2        Gemma Chan                      Action Thriller
# 3           unknown                                Drama
# 4    Patrick Wilson  Action Crime Drama Mystery Thriller
# ..              ...                                  ...
# 262    Rebecca Hall                       Mystery Comedy
# 263    Steve Carell                      Biography Drama
# 264  Justin Theroux                      Biography Drama
# 265    Toby Kebbell                       Crime Thriller
# 266   Asim Chaudhry                      Sci-Fi Thriller
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 262             holmes & watson
# 263                        vice
# 264         on the basis of sex
# 265                   destroyer
# 266  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 262  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 263  Christian Bale Amy Adams Steve Carell Adam McK...
# 264  Felicity Jones Armie Hammer Justin Theroux Mim...
# 265  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 266  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [267 rows x 7 columns]

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1             Title  \
# 0     JANUARY          4       Escape Room
# 1     JANUARY          4        Rust Creek
# 2     JANUARY          4  American Hangman
# 3     JANUARY         11  A Dog's Way Home
# 4     JANUARY         11        The Upside
# ..        ...        ...               ...
# 225  DECEMBER         25      Little Women
# 226  DECEMBER         25              1917
# 227  DECEMBER         25        Just Mercy
# 228  DECEMBER         27          Clemency
# 229  DECEMBER         27        Apparition
#
#                                   Production company  \
# 0                                  Columbia Pictures
# 1                                          IFC Films
# 2                        Hangman Justice Productions
# 3                                  Columbia Pictures
# 4                                  STX Entertainment
# ..                                               ...
# 225          Columbia Pictures / Regency Enterprises
# 226  Universal Pictures / DreamWorks Pictures / eOne
# 227        Warner Bros. Pictures / Participant Media
# 228                                             Neon
# 229                                Vertical Pictures
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Bragi F. Schut, Maria...
# 1    Jen McGowan (director); Julie Lipson (screenpl...
# 2    Wilson Coneybeare (director/screenplay); Donal...
# 3    Charles Martin Smith (director); W. Bruce Came...
# 4    Neil Burger (director); Jon Hartmere (screenpl...
# ..                                                 ...
# 225  Greta Gerwig (director/screenplay); Saoirse Ro...
# 226  Sam Mendes (director/screenplay); Krysty Wilso...
# 227  Destin Daniel Cretton (director/screenplay), A...
# 228  Chinonye Chukwu (director/screenplay); Alfre W...
# 229  Waymon Boone (director/screenplay); Mena Suvar...
#
#                             Genre   Ref.
# 0       Horror, Thriller, Mystery    [2]
# 1         Drama, Thriller, Horror    [3]
# 2                        Thriller    [4]
# 3                   Drama, Family    [5]
# 4                   Comedy, Drama    [6]
# ..                            ...    ...
# 225        Drama, Comedy, Romance  [211]
# 226  War, Action, Drama, Thriller  [212]
# 227              Biography, Drama  [213]
# 228                         Drama  [214]
# 229                        Horror  [215]
#
# [230 rows x 7 columns]

# %%
df_2019 = df[['Title','Cast and crew','Genre']]

# %%
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 225      Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 226              1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 227        Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 228          Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 229        Apparition  Waymon Boone (director/screenplay); Mena Suvar...
#
#                             Genre
# 0       Horror, Thriller, Mystery
# 1         Drama, Thriller, Horror
# 2                        Thriller
# 3                   Drama, Family
# 4                   Comedy, Drama
# ..                            ...
# 225        Drama, Comedy, Romance
# 226  War, Action, Drama, Thriller
# 227              Biography, Drama
# 228                         Drama
# 229                        Horror
#
# [230 rows x 3 columns]

# %%
df_2019['genres'] = df_2019['Genre'].str.replace(',', '')
# Out:
# /home/kishan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /home/kishan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /home/kishan/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#              director_name         actor_1_name          actor_2_name  \
# 0             Adam Robitel       Taylor Russell          Logan Miller
# 1              Jen McGowan    Hermione Corfield           Jay Paulson
# 2        Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3     Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4              Neil Burger       Bryan Cranston            Kevin Hart
# ..                     ...                  ...                   ...
# 225           Greta Gerwig        Saoirse Ronan           Emma Watson
# 226             Sam Mendes        George MacKay  Dean-Charles Chapman
# 227  Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 228        Chinonye Chukwu        Alfre Woodard        Wendell Pierce
# 229           Waymon Boone          Mena Suvari          Kevin Pollak
#
#          actor_3_name                     genres       movie_title  \
# 0    Deborah Ann Woll    Horror Thriller Mystery       escape room
# 1        Sean O'Bryan      Drama Thriller Horror        rust creek
# 2       Oliver Dennis                   Thriller  american hangman
# 3     Alexandra Shipp               Drama Family  a dog's way home
# 4       Nicole Kidman               Comedy Drama        the upside
# ..                ...                        ...               ...
# 225     Florence Pugh       Drama Comedy Romance      little women
# 226       Mark Strong  War Action Drama Thriller              1917
# 227       Brie Larson            Biography Drama        just mercy
# 228       Aldis Hodge                      Drama          clemency
# 229           unknown                     Horror        apparition
#
#                                                   comb
# 0    Taylor Russell Logan Miller Deborah Ann Woll A...
# 1    Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2    Donald Sutherland Vincent Kartheiser Oliver De...
# 3    Bryce Dallas Howard Edward James Olmos Alexand...
# 4    Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                                                 ...
# 225  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 226  George MacKay Dean-Charles Chapman Mark Strong...
# 227  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 228  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 229  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [230 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5856           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5857             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5858  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5859        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5860           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5856         Florence Pugh             Drama Comedy Romance
# 5857           Mark Strong        War Action Drama Thriller
# 5858           Brie Larson                  Biography Drama
# 5859           Aldis Hodge                            Drama
# 5860               unknown                           Horror
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5856                                       little women
# 5857                                               1917
# 5858                                         just mercy
# 5859                                           clemency
# 5860                                         apparition
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5856  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5857  George MacKay Dean-Charles Chapman Mark Strong...
# 5858  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5859  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5860  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5861 rows x 7 columns]

# %%
final_df.to_csv('final_data.csv',index=False)
