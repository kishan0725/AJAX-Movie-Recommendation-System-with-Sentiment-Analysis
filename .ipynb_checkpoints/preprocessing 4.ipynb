# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY        3.0         The Grudge
# 1     JANUARY       10.0         Underwater
# 2     JANUARY       10.0        Like a Boss
# 3     JANUARY       10.0  Inherit the Viper
# 4     JANUARY       10.0         The Sonata
# ..        ...        ...                ...
# 143  DECEMBER       23.0  Top Gun: Maverick
# 144  DECEMBER       23.0       The Croods 2
# 145  DECEMBER       25.0      The Last Duel
# 146  DECEMBER       25.0  News of the World
# 147  DECEMBER       25.0            Respect
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3       Barry Films / Tycor International Film Company
# 4                                   Screen Media Films
# ..                                                 ...
# 143  Paramount Pictures / Skydance Media / Don Simp...
# 144          Universal Pictures / DreamWorks Animation
# 145  20th Century Studios / Scott Free Productions ...
# 146             Universal Pictures / Columbia Pictures
# 147  Metro-Goldwyn-Mayer / Universal Pictures / Bro...
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# 4    Andrew Desmond (director/screenplay); Arthur M...    [6]
# ..                                                 ...    ...
# 143  Joseph Kosinski (director); Ehren Kruger, Eric...  [142]
# 144  Joel Crawford (director); Kevin Hageman, Dan H...  [143]
# 145  Ridley Scott (director); Ben Affleck, Matt Dam...  [144]
# 146  Paul Greengrass (director/screenplay); Luke Da...  [145]
# 147  Liesl Tommy (director); Tracey Scott Wilson (s...  [146]
#
# [148 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                  Title                                      Cast and crew
# 0           The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1           Underwater  William Eubank (director); Brian Duffield, Ada...
# 2          Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4           The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                 ...                                                ...
# 143  Top Gun: Maverick  Joseph Kosinski (director); Ehren Kruger, Eric...
# 144       The Croods 2  Joel Crawford (director); Kevin Hageman, Dan H...
# 145      The Last Duel  Ridley Scott (director); Ben Affleck, Matt Dam...
# 146  News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 147            Respect  Liesl Tommy (director); Tracey Scott Wilson (s...
#
# [148 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        genre_list = str(genres)
        return genre_list
#         return genre_str.join(genre_list)
    else:
        np.NaN

# %%
df_2020['Genre'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-14-03673a9a4aeb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['Genre'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                  Title                                      Cast and crew  \
# 0           The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1           Underwater  William Eubank (director); Brian Duffield, Ada...
# 2          Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4           The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                 ...                                                ...
# 143  Top Gun: Maverick  Joseph Kosinski (director); Ehren Kruger, Eric...
# 144       The Croods 2  Joel Crawford (director); Kevin Hageman, Dan H...
# 145      The Last Duel  Ridley Scott (director); Ben Affleck, Matt Dam...
# 146  News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 147            Respect  Liesl Tommy (director); Tracey Scott Wilson (s...
#
#                                                  Genre
# 0                                ['Horror', 'Mystery']
# 1    ['Horror', 'Science Fiction', 'Action', 'Thril...
# 2                                           ['Comedy']
# 3                       ['Drama', 'Thriller', 'Crime']
# 4                    ['Horror', 'Thriller', 'Mystery']
# ..                                                 ...
# 143                                ['Action', 'Drama']
# 144               ['Animation', 'Adventure', 'Family']
# 145                                          ['Drama']
# 146                               ['Drama', 'Western']
# 147                                 ['Music', 'Drama']
#
# [148 rows x 3 columns]

# %%
def list_to_string(x):
    if x:
        return x.replace(',', '').replace('[','').replace(']','').replace("'",'')
    else:
        return np.NaN

# %%
df_2020['genres'] = df_2020['Genre'].map(lambda x: list_to_string(x))
# Out:
# <ipython-input-17-0a2f4ad09b6e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Genre'].map(lambda x: list_to_string(x))

# %%
df_2020
# Out:
#                  Title                                      Cast and crew  \
# 0           The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1           Underwater  William Eubank (director); Brian Duffield, Ada...
# 2          Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4           The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                 ...                                                ...
# 143  Top Gun: Maverick  Joseph Kosinski (director); Ehren Kruger, Eric...
# 144       The Croods 2  Joel Crawford (director); Kevin Hageman, Dan H...
# 145      The Last Duel  Ridley Scott (director); Ben Affleck, Matt Dam...
# 146  News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 147            Respect  Liesl Tommy (director); Tracey Scott Wilson (s...
#
#                                                  Genre  \
# 0                                ['Horror', 'Mystery']
# 1    ['Horror', 'Science Fiction', 'Action', 'Thril...
# 2                                           ['Comedy']
# 3                       ['Drama', 'Thriller', 'Crime']
# 4                    ['Horror', 'Thriller', 'Mystery']
# ..                                                 ...
# 143                                ['Action', 'Drama']
# 144               ['Animation', 'Adventure', 'Family']
# 145                                          ['Drama']
# 146                               ['Drama', 'Western']
# 147                                 ['Music', 'Drama']
#
#                                      genres
# 0                            Horror Mystery
# 1    Horror Science Fiction Action Thriller
# 2                                    Comedy
# 3                      Drama Thriller Crime
# 4                   Horror Thriller Mystery
# ..                                      ...
# 143                            Action Drama
# 144              Animation Adventure Family
# 145                                   Drama
# 146                           Drama Western
# 147                             Music Drama
#
# [148 rows x 4 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-20-bc52fe9b0c35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                  Title                                      Cast and crew  \
# 0           The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1           Underwater  William Eubank (director); Brian Duffield, Ada...
# 2          Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# 4           The Sonata  Andrew Desmond (director/screenplay); Arthur M...
# ..                 ...                                                ...
# 143  Top Gun: Maverick  Joseph Kosinski (director); Ehren Kruger, Eric...
# 144       The Croods 2  Joel Crawford (director); Kevin Hageman, Dan H...
# 145      The Last Duel  Ridley Scott (director); Ben Affleck, Matt Dam...
# 146  News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 147            Respect  Liesl Tommy (director); Tracey Scott Wilson (s...
#
#                                                  Genre  \
# 0                                ['Horror', 'Mystery']
# 1    ['Horror', 'Science Fiction', 'Action', 'Thril...
# 2                                           ['Comedy']
# 3                       ['Drama', 'Thriller', 'Crime']
# 4                    ['Horror', 'Thriller', 'Mystery']
# ..                                                 ...
# 143                                ['Action', 'Drama']
# 144               ['Animation', 'Adventure', 'Family']
# 145                                          ['Drama']
# 146                               ['Drama', 'Western']
# 147                                 ['Music', 'Drama']
#
#                                      genres    director_name  \
# 0                            Horror Mystery    Nicolas Pesce
# 1    Horror Science Fiction Action Thriller   William Eubank
# 2                                    Comedy    Miguel Arteta
# 3                      Drama Thriller Crime   Anthony Jerjen
# 4                   Horror Thriller Mystery   Andrew Desmond
# ..                                      ...              ...
# 143                            Action Drama  Joseph Kosinski
# 144              Animation Adventure Family    Joel Crawford
# 145                                   Drama     Ridley Scott
# 146                           Drama Western  Paul Greengrass
# 147                             Music Drama      Liesl Tommy
#
#            actor_1_name       actor_2_name       actor_3_name
# 0    Andrea Riseborough      Demián Bichir           John Cho
# 1       Kristen Stewart     Vincent Cassel    Jessica Henwick
# 2       Tiffany Haddish         Rose Byrne        Salma Hayek
# 3         Josh Hartnett  Margarita Levieva     Chandler Riggs
# 4         Freya Tingley     Simon Abkarian       Rutger Hauer
# ..                  ...                ...                ...
# 143          Tom Cruise       Miles Teller  Jennifer Connelly
# 144        Nicolas Cage         Emma Stone      Ryan Reynolds
# 145          Matt Damon        Adam Driver        Jodie Comer
# 146           Tom Hanks      Helena Zengel    Neil Sandilands
# 147     Jennifer Hudson    Forest Whitaker      Marlon Wayans
#
# [148 rows x 8 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#        director_name        actor_1_name       actor_2_name  \
# 0      Nicolas Pesce  Andrea Riseborough      Demián Bichir
# 1     William Eubank     Kristen Stewart     Vincent Cassel
# 2      Miguel Arteta     Tiffany Haddish         Rose Byrne
# 3     Anthony Jerjen       Josh Hartnett  Margarita Levieva
# 4     Andrew Desmond       Freya Tingley     Simon Abkarian
# ..               ...                 ...                ...
# 143  Joseph Kosinski          Tom Cruise       Miles Teller
# 144    Joel Crawford        Nicolas Cage         Emma Stone
# 145     Ridley Scott          Matt Damon        Adam Driver
# 146  Paul Greengrass           Tom Hanks      Helena Zengel
# 147      Liesl Tommy     Jennifer Hudson    Forest Whitaker
#
#           actor_3_name                                  genres  \
# 0             John Cho                          Horror Mystery
# 1      Jessica Henwick  Horror Science Fiction Action Thriller
# 2          Salma Hayek                                  Comedy
# 3       Chandler Riggs                    Drama Thriller Crime
# 4         Rutger Hauer                 Horror Thriller Mystery
# ..                 ...                                     ...
# 143  Jennifer Connelly                            Action Drama
# 144      Ryan Reynolds              Animation Adventure Family
# 145        Jodie Comer                                   Drama
# 146    Neil Sandilands                           Drama Western
# 147      Marlon Wayans                             Music Drama
#
#            movie_title
# 0           The Grudge
# 1           Underwater
# 2          Like a Boss
# 3    Inherit the Viper
# 4           The Sonata
# ..                 ...
# 143  Top Gun: Maverick
# 144       The Croods 2
# 145      The Last Duel
# 146  News of the World
# 147            Respect
#
# [148 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20['actor_2_name'] = new_df20['actor_2_name'].replace(np.nan, 'unknown')
new_df20['actor_3_name'] = new_df20['actor_3_name'].replace(np.nan, 'unknown')
new_df20['director_name'] = new_df20['director_name'].replace(np.nan, 'unknown')
new_df20['movie_title'] = new_df20['movie_title'].replace(np.nan, 'unknown')
new_df20['actor_1_name'] = new_df20['actor_1_name'].replace(np.nan, 'unknown')
new_df20['comb'] = new_df20['comb'].replace(np.nan, 'unknown')
new_df20['genres'] = new_df20['genres'].replace(np.nan, 'unknown')

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#        director_name        actor_1_name       actor_2_name  \
# 0      Nicolas Pesce  Andrea Riseborough      Demián Bichir
# 1     William Eubank     Kristen Stewart     Vincent Cassel
# 2      Miguel Arteta     Tiffany Haddish         Rose Byrne
# 3     Anthony Jerjen       Josh Hartnett  Margarita Levieva
# 4     Andrew Desmond       Freya Tingley     Simon Abkarian
# ..               ...                 ...                ...
# 143  Joseph Kosinski          Tom Cruise       Miles Teller
# 144    Joel Crawford        Nicolas Cage         Emma Stone
# 145     Ridley Scott          Matt Damon        Adam Driver
# 146  Paul Greengrass           Tom Hanks      Helena Zengel
# 147      Liesl Tommy     Jennifer Hudson    Forest Whitaker
#
#           actor_3_name                                  genres  \
# 0             John Cho                          Horror Mystery
# 1      Jessica Henwick  Horror Science Fiction Action Thriller
# 2          Salma Hayek                                  Comedy
# 3       Chandler Riggs                    Drama Thriller Crime
# 4         Rutger Hauer                 Horror Thriller Mystery
# ..                 ...                                     ...
# 143  Jennifer Connelly                            Action Drama
# 144      Ryan Reynolds              Animation Adventure Family
# 145        Jodie Comer                                   Drama
# 146    Neil Sandilands                           Drama Western
# 147      Marlon Wayans                             Music Drama
#
#            movie_title                                               comb
# 0           the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1           underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2          like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3    inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# 4           the sonata  Freya Tingley Simon Abkarian Rutger Hauer Andr...
# ..                 ...                                                ...
# 143  top gun: maverick  Tom Cruise Miles Teller Jennifer Connelly Jose...
# 144       the croods 2  Nicolas Cage Emma Stone Ryan Reynolds Joel Cra...
# 145      the last duel  Matt Damon Adam Driver Jodie Comer Ridley Scot...
# 146  news of the world  Tom Hanks Helena Zengel Neil Sandilands Paul G...
# 147            respect  Jennifer Hudson Forest Whitaker Marlon Wayans ...
#
# [148 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5856           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5857             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5858  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5859        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5860           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5856         Florence Pugh             Drama Comedy Romance
# 5857           Mark Strong        War Action Drama Thriller
# 5858           Brie Larson                  Biography Drama
# 5859           Aldis Hodge                            Drama
# 5860               unknown                           Horror
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5856                                       little women
# 5857                                               1917
# 5858                                         just mercy
# 5859                                           clemency
# 5860                                         apparition
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5856  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5857  George MacKay Dean-Charles Chapman Mark Strong...
# 5858  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5859  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5860  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5861 rows x 7 columns]

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6004    Joseph Kosinski       Tom Cruise      Miles Teller
# 6005      Joel Crawford     Nicolas Cage        Emma Stone
# 6006       Ridley Scott       Matt Damon       Adam Driver
# 6007    Paul Greengrass        Tom Hanks     Helena Zengel
# 6008        Liesl Tommy  Jennifer Hudson   Forest Whitaker
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6004     Jennifer Connelly                     Action Drama
# 6005         Ryan Reynolds       Animation Adventure Family
# 6006           Jodie Comer                            Drama
# 6007       Neil Sandilands                    Drama Western
# 6008         Marlon Wayans                      Music Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6004                                  top gun: maverick
# 6005                                       the croods 2
# 6006                                      the last duel
# 6007                                  news of the world
# 6008                                            respect
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6004  Tom Cruise Miles Teller Jennifer Connelly Jose...
# 6005  Nicolas Cage Emma Stone Ryan Reynolds Joel Cra...
# 6006  Matt Damon Adam Driver Jodie Comer Ridley Scot...
# 6007  Tom Hanks Helena Zengel Neil Sandilands Paul G...
# 6008  Jennifer Hudson Forest Whitaker Marlon Wayans ...
#
# [6009 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
